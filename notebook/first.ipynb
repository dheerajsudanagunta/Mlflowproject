# %% [markdown]
# # ML flow tracking

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("check localhost experiment")

with mlflow.start_run():
    mlflow.log_metric("m1", 1)
    mlflow.log_metric("m2", 2)
# Out:
# 🏃 View run industrious-mule-897 at: http://127.0.0.1:5000/#/experiments/1/runs/bf0974b111f441e08c4d29b54e474746
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("m1", 3)
    mlflow.log_metric("m2", 4)
# Out:
# 🏃 View run fearless-frog-110 at: http://127.0.0.1:5000/#/experiments/1/runs/9fdd399febb149f4a4f2fb216c73ac05
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
